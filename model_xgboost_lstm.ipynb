# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import xgboost as xgb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/data scientist/FinanceResearch/data/TSLA.csv')

# %%
df.head(15)
# Out:
#           Date     Close     lag_1     lag_5    lag_10        r1        r2  \
# 0   2010-06-29  1.588667  1.592667  1.592667  1.592667 -0.002515 -0.002515
# 1   2010-06-30  1.464000  1.588667  1.592667  1.592667 -0.002515 -0.002515
# 2   2010-07-01  1.280000  1.464000  1.592667  1.592667 -0.081723 -0.002515
# 3   2010-07-02  1.074000  1.280000  1.592667  1.592667 -0.134312 -0.081723
# 4   2010-07-06  1.053333  1.074000  1.592667  1.592667 -0.175470 -0.134312
# 5   2010-07-07  1.164000  1.053333  1.588667  1.592667 -0.019431 -0.175470
# 6   2010-07-08  1.160000  1.164000  1.464000  1.592667  0.099903 -0.019431
# 7   2010-07-09  1.136667  1.160000  1.280000  1.592667 -0.003442  0.099903
# 8   2010-07-12  1.209333  1.136667  1.074000  1.592667 -0.020320 -0.003442
# 9   2010-07-13  1.322667  1.209333  1.053333  1.592667  0.061969 -0.020320
# 10  2010-07-14  1.326000  1.322667  1.164000  1.588667  0.089581  0.061969
# 11  2010-07-15  1.376000  1.326000  1.160000  1.464000  0.002517  0.089581
# 12  2010-07-16  1.460667  1.376000  1.136667  1.280000  0.037014  0.002517
# 13  2010-07-19  1.353333  1.460667  1.209333  1.074000  0.059712  0.037014
# 14  2010-07-20  1.348000  1.353333  1.322667  1.053333 -0.076323  0.059712
#
#           r3        r4        r5  ...       r11       r12       r13       r14  \
# 0  -0.002515 -0.002515  0.274437  ...  0.274437 -0.079956 -0.079956 -0.079956
# 1  -0.002515 -0.002515  0.165114  ...  0.274437 -0.101533 -0.079956 -0.079956
# 2  -0.002515 -0.002515  0.036139  ...  0.274437 -0.209734 -0.101533 -0.079956
# 3  -0.002515 -0.002515  0.004339  ...  0.274437 -0.206436 -0.209734 -0.101533
# 4  -0.081723 -0.002515  0.000000  ...  0.165114 -0.233825 -0.206436 -0.209734
# 5  -0.134312 -0.081723  0.013928  ...  0.036139 -0.090565 -0.233825 -0.206436
# 6  -0.175470 -0.134312  0.082042  ...  0.004339 -0.035955 -0.090565 -0.233825
# 7  -0.019431 -0.175470  0.018039  ...  0.000000 -0.060376 -0.035955 -0.090565
# 8   0.099903 -0.019431  0.006663  ...  0.013928 -0.054377 -0.060376 -0.035955
# 9  -0.003442  0.099903  0.069415  ...  0.082042 -0.028581 -0.054377 -0.060376
# 10 -0.020320 -0.003442  0.116171  ...  0.018039 -0.010084 -0.028581 -0.054377
# 11  0.061969 -0.020320  0.075325  ...  0.006663 -0.048288 -0.010084 -0.028581
# 12  0.089581  0.061969  0.028573  ...  0.069415 -0.031904 -0.048288 -0.010084
# 13  0.002517  0.089581  0.040353  ...  0.116171 -0.021282 -0.031904 -0.048288
# 14  0.037014  0.002517  0.000000  ...  0.075325 -0.085972 -0.021282 -0.031904
#
#          r15        RSI  Momentum  TrueRange       ATR  ParabolicSAR
# 0  -0.079956  43.408794 -0.270000   0.497334  0.211714      1.592667
# 1  -0.079956  43.408794 -0.270000   0.474667  0.211714      1.588667
# 2  -0.079956  43.408794 -0.270000   0.376667  0.211714      1.464000
# 3  -0.079956  43.408794 -0.270000   0.292667  0.211714      1.280000
# 4  -0.101533  43.408794 -0.270000   0.278000  0.211714      1.074000
# 5  -0.209734  43.408794 -0.270000   0.110000  0.211714      1.053333
# 6  -0.206436  43.408794 -0.270000   0.130000  0.211714      1.164000
# 7  -0.233825  43.408794 -0.270000   0.090000  0.211714      1.160000
# 8  -0.090565  43.408794 -0.270000   0.071334  0.211714      1.136667
# 9  -0.035955  43.408794 -0.270000   0.116000  0.211714      1.209333
# 10 -0.060376  43.408794 -0.270000   0.159333  0.211714      1.322667
# 11 -0.054377  43.408794 -0.262667   0.166666  0.211714      1.326000
# 12 -0.028581  43.408794 -0.088000   0.094000  0.211714      1.376000
# 13 -0.010084  43.408794  0.180667   0.107333  0.211714      1.460667
# 14 -0.048288  39.206237  0.279333   0.124000  0.185048      1.353333
#
# [15 rows x 25 columns]

# %%
df.isna().sum()
# Out:
# Date            0
# Close           1
# lag_1           0
# lag_5           0
# lag_10          0
# r1              0
# r2              0
# r3              0
# r4              0
# r5              0
# r6              0
# r7              0
# r8              0
# r9              0
# r10             0
# r11             0
# r12             0
# r13             0
# r14             0
# r15             0
# RSI             0
# Momentum        0
# TrueRange       0
# ATR             0
# ParabolicSAR    0
# dtype: int64

# %%
def prepare_data(stock_data, sequence_length=10, target_column='Close', train_size=325, test_size=125, step=125):
    """
    Chuẩn bị dữ liệu cho mô hình LSTM và XGBoost, bao gồm chuẩn hóa và dịch chuyển tập huấn luyện, kiểm tra.

    Parameters:
    -----------
    stock_data : pandas DataFrame
        Dữ liệu cổ phiếu đã được xử lý
    sequence_length : int
        Độ dài chuỗi thời gian cho LSTM
    target_column : str
        Tên cột dữ liệu mục tiêu cần dự đoán
    train_size : int
        Số lượng mẫu dành cho tập huấn luyện
    test_size : int
        Số lượng mẫu dành cho tập kiểm tra
    step : int
        Số lượng mẫu dịch chuyển giữa các lần huấn luyện

    Returns:
    --------
    List chứa các bộ dữ liệu huấn luyện và kiểm tra đã xử lý cho LSTM và XGBoost
    """
    stock_data['Date'] = pd.to_datetime(stock_data['Date'])
    stock_data = stock_data.sort_values('Date').reset_index(drop=True)
    datasets = []

    for start_idx in range(0, len(stock_data) - (train_size + test_size), step):
        df_train = stock_data.iloc[start_idx:start_idx + train_size]
        df_test = stock_data.iloc[start_idx + train_size - sequence_length:start_idx + train_size + test_size]

        feature_columns = [col for col in stock_data.columns if col not in ['Date', target_column]]

        X_train = df_train[feature_columns].values
        X_test = df_test[feature_columns].values
        y_train = df_train[target_column].values
        y_test = df_test[target_column].values

        # Chuẩn hóa dữ liệu
        scaler_X = MinMaxScaler(feature_range=(0, 1))
        scaler_y = MinMaxScaler(feature_range=(0, 1))

        X_train_scaled = scaler_X.fit_transform(X_train)
        X_test_scaled = scaler_X.transform(X_test)

        y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1))
        y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1))

        # Chuẩn bị dữ liệu cho XGBoost
        X_train_xgb = X_train_scaled
        X_test_xgb = X_test_scaled
        y_train_xgb = y_train_scaled.flatten()
        y_test_xgb = y_test_scaled.flatten()

        # Chuẩn bị dữ liệu cho LSTM
        X_sequences, y_sequences = [], []
        for i in range(len(X_train_scaled) - sequence_length):
            X_sequences.append(X_train_scaled[i:i + sequence_length])
            y_sequences.append(y_train_scaled[i + sequence_length])

        X_sequences = np.array(X_sequences)
        y_sequences = np.array(y_sequences)

        X_test_sequences, y_test_sequences = [], []
        for i in range(len(X_test_scaled) - sequence_length):
            X_test_sequences.append(X_test_scaled[i:i + sequence_length])
            y_test_sequences.append(y_test_scaled[i + sequence_length])

        X_test_sequences = np.array(X_test_sequences)
        y_test_sequences = np.array(y_test_sequences)

        datasets.append({
            'xgboost': {
                'X_train': X_train_xgb,
                'y_train': y_train_xgb,
                'X_test': X_test_xgb[sequence_length:],
                'y_test': y_test_xgb[sequence_length:],
                'feature_names': feature_columns,
                'scaler_X': scaler_X,
                'scaler_y': scaler_y
            },
            'lstm': {
                'X_train': X_sequences,
                'y_train': y_sequences,
                'X_test': X_test_sequences,
                'y_test': y_test_sequences,
                'scaler_y': scaler_y,
                'scaler_X': scaler_X,
                'sequence_length': sequence_length
            },
            'dates_test': df_test['Date'].values[sequence_length:],
            'actual_test': y_test[sequence_length:]
        })

    return datasets

# %%
def build_lstm_model(prepared_data, units=50, dropout_rate=0.2, learning_rate=0.001, epochs=100, batch_size=32, patience=10):
    """
    Xây dựng và huấn luyện mô hình LSTM

    Parameters:
    -----------
    prepared_data : dict
        Dictionary chứa dữ liệu đã chuẩn bị cho LSTM
    units : int
        Số lượng units trong layer LSTM
    dropout_rate : float
        Tỷ lệ dropout để tránh overfitting
    learning_rate : float
        Tốc độ học của optimizer
    epochs : int
        Số lượng epochs huấn luyện
    batch_size : int
        Kích thước batch
    patience : int
        Số epochs đợi trước khi early stopping

    Returns:
    --------
    Mô hình LSTM đã huấn luyện và kết quả dự đoán
    """

    X_train = prepared_data['lstm']['X_train']
    y_train = prepared_data['lstm']['y_train']
    X_test = prepared_data['lstm']['X_test']
    scaler_y = prepared_data['lstm']['scaler_y']


    input_shape = (X_train.shape[1], X_train.shape[2])

    model = Sequential()
    model.add(LSTM(units=units, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=units, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error')

    early_stopping = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.1,
        callbacks=[early_stopping],
        verbose=1
    )

    y_pred_scaled = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred_scaled)

    return {
        'model': model,
        'history': history,
        'predictions': y_pred.flatten(),
        'predictions_scaled': y_pred_scaled.flatten()
    }

# %%
def build_xgboost_model(prepared_data, max_depth=7, learning_rate=0.1, n_estimators=100, early_stopping_rounds=10):
    """
    Xây dựng và huấn luyện mô hình XGBoost với dữ liệu đã chuẩn hóa

    Parameters:
    -----------
    prepared_data : dict
        Dictionary chứa dữ liệu đã chuẩn bị cho XGBoost
    max_depth : int
        Độ sâu tối đa của cây
    learning_rate : float
        Tốc độ học của mô hình
    n_estimators : int
        Số lượng cây ước lượng
    early_stopping_rounds : int
        Số vòng đợi trước khi early stopping

    Returns:
    --------
    Mô hình XGBoost đã huấn luyện và kết quả dự đoán
    """
    # Lấy dữ liệu
    X_train = prepared_data['xgboost']['X_train']
    y_train = prepared_data['xgboost']['y_train']
    X_test = prepared_data['xgboost']['X_test']
    feature_names = prepared_data['xgboost']['feature_names']
    scaler_y = prepared_data['xgboost']['scaler_y']

    X_train_xgb, X_val_xgb, y_train_xgb, y_val_xgb = train_test_split(
        X_train, y_train, test_size=0.1, random_state=42
    )

    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        max_depth=max_depth,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        random_state=42,
        n_jobs=-1
    )

    model.fit(
        X_train_xgb, y_train_xgb,
        eval_set=[(X_val_xgb, y_val_xgb)],
        verbose=False
    )

    y_pred_scaled = model.predict(X_test)

    y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
    feature_importance = model.feature_importances_
    feature_importance_dict = {feature: importance for feature, importance in zip(feature_names, feature_importance)}

    return {
        'model': model,
        'predictions': y_pred,
        'predictions_scaled': y_pred_scaled,
        'feature_importance': feature_importance_dict
    }

# %%
def evaluate_models(actual, lstm_pred, xgb_pred):
    results = {}
    all_predicts = {}
    # Đánh giá LSTM
    results['lstm'] = {
        'rmse': np.sqrt(mean_squared_error(actual, lstm_pred)),
        'mae': mean_absolute_error(actual, lstm_pred),
        'r2': r2_score(actual, lstm_pred),
        'mse': mean_squared_error(actual, lstm_pred)
    }

    # Đánh giá XGBoost
    results['xgboost'] = {
        'rmse': np.sqrt(mean_squared_error(actual, xgb_pred)),
        'mae': mean_absolute_error(actual, xgb_pred),
        'r2': r2_score(actual, xgb_pred),
        'mse': mean_squared_error(actual, xgb_pred)
    }

    all_predicts = {"actual": actual.tolist(),
                    "lstm_predict": lstm_pred.tolist(),
                    "xgboost_predict": xgb_pred.tolist()}

    # So sánh hiệu suất
    print("Đánh giá mô hình LSTM:")
    print(f"RMSE: {results['lstm']['rmse']:.4f}")
    print(f"MAE: {results['lstm']['mae']:.4f}")
    print(f"R²: {results['lstm']['r2']:.4f}")
    print("\nĐánh giá mô hình XGBoost:")
    print(f"RMSE: {results['xgboost']['rmse']:.4f}")
    print(f"MAE: {results['xgboost']['mae']:.4f}")
    print(f"R²: {results['xgboost']['r2']:.4f}")

    return results, all_predicts

# %% [markdown]
# # Xây dựng model

# %%
import json
sequence_length = 60
results_summary = {}
for stock_code in ['TSLA', 'SSE', 'STAN', 'STJ', 'TSCO']:
    print(f"⏳ PROCESSING!, Processing stock code: {stock_code}")
    df = pd.read_csv(f'/content/drive/MyDrive/data scientist/FinanceResearch/data/{stock_code}.csv')
    datasets = prepare_data(df, sequence_length=sequence_length, train_size=750, test_size=250, step=250)

    stock_results = []
    for data in datasets:
        print("🚀 Running lstm")
        lstm_model = build_lstm_model(data, epochs=50, batch_size=16, patience=10)
        print("🚀 Running xgboost")
        xgb_model = build_xgboost_model(data)

        print("🚀 Evaluating")
        results, all_predicts = evaluate_models(
            data['actual_test'],
            lstm_model['predictions'],
            xgb_model['predictions']
        )

        stock_results.append({
            'results': {k: v.tolist() if isinstance(v, np.ndarray) else v for k, v in results.items()},
            'predictions': {k: v.tolist() if isinstance(v, np.ndarray) else v for k, v in all_predicts.items()},
            'dates_test': list(data['dates_test'])
        })

    results_summary[stock_code] = stock_results
    print(f"✅ DONE! Finished processing stock code: {stock_code}")
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - loss: 0.0379 - val_loss: 0.1733
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0038 - val_loss: 0.1474
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0026 - val_loss: 0.1097
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0017 - val_loss: 0.0765
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0014 - val_loss: 0.0818
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0013 - val_loss: 0.0806
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0011 - val_loss: 0.0728
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 6.8525e-04 - val_loss: 0.0671
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 7.2066e-04 - val_loss: 0.0658
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 7.4084e-04 - val_loss: 0.0676
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 6.4634e-04 - val_loss: 0.0617
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 6.7816e-04 - val_loss: 0.0659
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 7.5676e-04 - val_loss: 0.0792
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 7.5346e-04 - val_loss: 0.0624
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 6.6143e-04 - val_loss: 0.0604
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 6.1312e-04 - val_loss: 0.0687
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 6.9419e-04 - val_loss: 0.0650
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - loss: 6.0312e-04 - val_loss: 0.0611
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - loss: 4.8654e-04 - val_loss: 0.0620
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.4777e-04 - val_loss: 0.0586
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.5520e-04 - val_loss: 0.0634
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 6.0761e-04 - val_loss: 0.0643
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.6178e-04 - val_loss: 0.0602
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 5.0304e-04 - val_loss: 0.0686
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 5.1229e-04 - val_loss: 0.0612
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 4.4424e-04 - val_loss: 0.0561
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 4.3801e-04 - val_loss: 0.0599
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 5.0538e-04 - val_loss: 0.0667
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 4.3947e-04 - val_loss: 0.0614
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.6716e-04 - val_loss: 0.0660
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.5787e-04 - val_loss: 0.0568
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.8701e-04 - val_loss: 0.0590
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 4.4173e-04 - val_loss: 0.0560
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.2806e-04 - val_loss: 0.0643
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.9225e-04 - val_loss: 0.0639
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 3.7441e-04 - val_loss: 0.0563
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - loss: 4.6465e-04 - val_loss: 0.0659
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.7074e-04 - val_loss: 0.0556
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.2053e-04 - val_loss: 0.0627
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 4.0097e-04 - val_loss: 0.0644
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 3.8332e-04 - val_loss: 0.0638
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.0975e-04 - val_loss: 0.0591
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.6876e-04 - val_loss: 0.0586
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.5776e-04 - val_loss: 0.0581
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.9757e-04 - val_loss: 0.0620
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 3.1838e-04 - val_loss: 0.0568
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.3562e-04 - val_loss: 0.0555
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 3.4786e-04 - val_loss: 0.0548
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.2447e-04 - val_loss: 0.0536
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 3.7089e-04 - val_loss: 0.0567
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Đánh giá mô hình LSTM:
# RMSE: 5.8908
# MAE: 5.5372
# R²: -4.8924
#
# Đánh giá mô hình XGBoost:
# RMSE: 5.7477
# MAE: 5.2020
# R²: -4.6096
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 0.0465 - val_loss: 0.0061
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0060 - val_loss: 0.0084
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0044 - val_loss: 0.0124
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0031 - val_loss: 0.0071
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0018 - val_loss: 0.0081
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0026 - val_loss: 0.0028
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0018 - val_loss: 0.0160
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0022 - val_loss: 0.0102
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0020 - val_loss: 0.0025
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Đánh giá mô hình LSTM:
# RMSE: 0.7571
# MAE: 0.6084
# R²: 0.7614
#
# Đánh giá mô hình XGBoost:
# RMSE: 0.9500
# MAE: 0.6743
# R²: 0.6244
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 0.0525 - val_loss: 0.0019
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0097 - val_loss: 6.7104e-04
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0083 - val_loss: 5.3945e-04
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0082 - val_loss: 0.0018
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0057 - val_loss: 7.3773e-04
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0050 - val_loss: 4.2423e-04
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0064 - val_loss: 3.8466e-04
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0046 - val_loss: 4.5616e-04
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0043 - val_loss: 5.4411e-04
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0042 - val_loss: 9.6757e-04
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0045 - val_loss: 3.9992e-04
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0041 - val_loss: 0.0023
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0049 - val_loss: 6.5564e-04
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0035 - val_loss: 5.5296e-04
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0055 - val_loss: 4.8816e-04
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7821bdd1d8a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# Đánh giá mô hình LSTM:
# RMSE: 0.8276
# MAE: 0.6730
# R²: 0.7947
#
# Đánh giá mô hình XGBoost:
# RMSE: 0.4642
# MAE: 0.3521
# R²: 0.9354
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.1142 - val_loss: 0.0226
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0148 - val_loss: 0.0065
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0110 - val_loss: 0.0059
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0093 - val_loss: 0.0048
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0093 - val_loss: 0.0134
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0087 - val_loss: 0.0041
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0077 - val_loss: 0.0097
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0091 - val_loss: 0.0040
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0083 - val_loss: 0.0041
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0067 - val_loss: 0.0033
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0070 - val_loss: 0.0050
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0073 - val_loss: 0.0032
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0056 - val_loss: 0.0034
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0071 - val_loss: 0.0034
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0062 - val_loss: 0.0041
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0061 - val_loss: 0.0031
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0062 - val_loss: 0.0031
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0066 - val_loss: 0.0053
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0055 - val_loss: 0.0048
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0054 - val_loss: 0.0029
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0055 - val_loss: 0.0038
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0053 - val_loss: 0.0030
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0059 - val_loss: 0.0048
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0057 - val_loss: 0.0058
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0057 - val_loss: 0.0029
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0047 - val_loss: 0.0028
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0066 - val_loss: 0.0034
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0057 - val_loss: 0.0025
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0057 - val_loss: 0.0042
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0050 - val_loss: 0.0028
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0042 - val_loss: 0.0031
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7821c4425bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Đánh giá mô hình LSTM:
# RMSE: 0.9137
# MAE: 0.6444
# R²: 0.9095
#
# Đánh giá mô hình XGBoost:
# RMSE: 1.6908
# MAE: 0.9287
# R²: 0.6900
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - loss: 0.0694 - val_loss: 0.0732
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0072 - val_loss: 0.0183
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0042 - val_loss: 0.0235
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0045 - val_loss: 0.0188
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0032 - val_loss: 0.0195
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0035 - val_loss: 0.0257
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0033 - val_loss: 0.0219
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0036 - val_loss: 0.0131
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0032 - val_loss: 0.0142
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0028 - val_loss: 0.0165
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0032 - val_loss: 0.0108
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0026 - val_loss: 0.0145
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0027 - val_loss: 0.0114
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0025 - val_loss: 0.0157
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0027 - val_loss: 0.0132
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0028 - val_loss: 0.0081
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0030 - val_loss: 0.0144
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0026 - val_loss: 0.0144
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0023 - val_loss: 0.0091
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0025 - val_loss: 0.0138
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0028 - val_loss: 0.0069
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0026 - val_loss: 0.0079
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0021 - val_loss: 0.0155
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0022 - val_loss: 0.0154
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0023 - val_loss: 0.0138
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0020 - val_loss: 0.0142
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0021 - val_loss: 0.0123
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0020 - val_loss: 0.0126
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0022 - val_loss: 0.0160
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0020 - val_loss: 0.0088
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# Đánh giá mô hình LSTM:
# RMSE: 1.5408
# MAE: 1.2846
# R²: 0.2766
#
# Đánh giá mô hình XGBoost:
# RMSE: 0.8912
# MAE: 0.6737
# R²: 0.7580
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - loss: 0.1537 - val_loss: 0.0062
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0105 - val_loss: 0.0067
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0093 - val_loss: 0.0114
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0093 - val_loss: 0.0061
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0076 - val_loss: 0.0044
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0070 - val_loss: 0.0040
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0052 - val_loss: 0.0088
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0048 - val_loss: 0.0040
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0042 - val_loss: 0.0063
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0041 - val_loss: 0.0039
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 0.0047 - val_loss: 0.0044
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0035 - val_loss: 0.0037
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0044 - val_loss: 0.0036
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0037 - val_loss: 0.0041
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0044 - val_loss: 0.0035
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0036 - val_loss: 0.0058
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 0.0028 - val_loss: 0.0053
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.0033 - val_loss: 0.0086
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0041 - val_loss: 0.0040
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Đánh giá mô hình LSTM:
# RMSE: 1.0770
# MAE: 0.8617
# R²: 0.8585
#
# Đánh giá mô hình XGBoost:
# RMSE: 0.8387
# MAE: 0.6126
# R²: 0.9142
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 0.0505 - val_loss: 0.0233
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0126 - val_loss: 0.0209
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0121 - val_loss: 0.0187
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0101 - val_loss: 0.0148
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0100 - val_loss: 0.0222
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0095 - val_loss: 0.0063
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0090 - val_loss: 0.0057
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0088 - val_loss: 0.0049
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0084 - val_loss: 0.0073
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0083 - val_loss: 0.0042
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0071 - val_loss: 0.0125
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0082 - val_loss: 0.0048
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0082 - val_loss: 0.0057
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0065 - val_loss: 0.0093
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0065 - val_loss: 0.0043
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0076 - val_loss: 0.0048
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0071 - val_loss: 0.0054
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step
# Đánh giá mô hình LSTM:
# RMSE: 14.0089
# MAE: 9.0332
# R²: 0.1189
#
# Đánh giá mô hình XGBoost:
# RMSE: 14.7145
# MAE: 9.0450
# R²: 0.0279
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - loss: 0.0543 - val_loss: 0.1331
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0096 - val_loss: 0.1160
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0037 - val_loss: 0.0853
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0032 - val_loss: 0.0632
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0029 - val_loss: 0.0297
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0023 - val_loss: 0.0438
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - loss: 0.0027 - val_loss: 0.0286
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0027 - val_loss: 0.0368
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0022 - val_loss: 0.0279
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0021 - val_loss: 0.0252
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0021 - val_loss: 0.0233
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0021 - val_loss: 0.0281
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0017 - val_loss: 0.0372
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0019 - val_loss: 0.0245
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0016 - val_loss: 0.0274
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0022 - val_loss: 0.0222
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0031 - val_loss: 0.0217
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0017 - val_loss: 0.0244
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0015 - val_loss: 0.0246
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0014 - val_loss: 0.0280
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0015 - val_loss: 0.0232
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0030 - val_loss: 0.0201
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0022 - val_loss: 0.0240
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0020 - val_loss: 0.0260
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0012 - val_loss: 0.0262
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0013 - val_loss: 0.0477
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0017 - val_loss: 0.0387
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0017 - val_loss: 0.0292
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0012 - val_loss: 0.0294
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0014 - val_loss: 0.0324
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0011 - val_loss: 0.0211
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0014 - val_loss: 0.0414
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# Đánh giá mô hình LSTM:
# RMSE: 126.0568
# MAE: 110.2405
# R²: -2.8164
#
# Đánh giá mô hình XGBoost:
# RMSE: 137.2036
# MAE: 121.1805
# R²: -3.5212
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0550 - val_loss: 0.0037
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0054 - val_loss: 0.0141
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0036 - val_loss: 0.0066
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0031 - val_loss: 0.0081
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0028 - val_loss: 0.0077
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0034 - val_loss: 0.0138
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0026 - val_loss: 0.0093
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0022 - val_loss: 0.0092
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0022 - val_loss: 0.0143
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0019 - val_loss: 0.0026
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Đánh giá mô hình LSTM:
# RMSE: 35.8752
# MAE: 26.7961
# R²: 0.5828
#
# Đánh giá mô hình XGBoost:
# RMSE: 49.9969
# MAE: 35.6763
# R²: 0.1897
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - loss: 0.1026 - val_loss: 0.0096
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0084 - val_loss: 0.0095
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0040 - val_loss: 0.0059
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0037 - val_loss: 0.0075
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0036 - val_loss: 0.0044
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0034 - val_loss: 0.0041
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0033 - val_loss: 0.0038
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0036 - val_loss: 0.0078
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0033 - val_loss: 0.0035
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0030 - val_loss: 0.0036
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0027 - val_loss: 0.0047
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0032 - val_loss: 0.0032
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0022 - val_loss: 0.0033
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0023 - val_loss: 0.0061
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0021 - val_loss: 0.0030
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# Đánh giá mô hình LSTM:
# RMSE: 12.3517
# MAE: 9.9924
# R²: 0.9416
#
# Đánh giá mô hình XGBoost:
# RMSE: 10.5985
# MAE: 8.3646
# R²: 0.9570
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 0.0832 - val_loss: 0.0011
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0138 - val_loss: 0.0033
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 0.0093 - val_loss: 0.0012
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0076 - val_loss: 0.0015
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0060 - val_loss: 0.0011
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0055 - val_loss: 7.7087e-04
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0046 - val_loss: 6.5799e-04
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0055 - val_loss: 7.1981e-04
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - loss: 0.0049 - val_loss: 9.1416e-04
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0042 - val_loss: 6.8440e-04
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0056 - val_loss: 8.4541e-04
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0046 - val_loss: 6.2269e-04
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0039 - val_loss: 7.6991e-04
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0042 - val_loss: 6.8517e-04
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 0.0033 - val_loss: 6.4523e-04
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0047 - val_loss: 0.0010
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0040 - val_loss: 7.3379e-04
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0038 - val_loss: 6.2006e-04
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - loss: 0.0035 - val_loss: 9.5562e-04
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0035 - val_loss: 7.5081e-04
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0037 - val_loss: 6.4982e-04
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0034 - val_loss: 8.7540e-04
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0034 - val_loss: 8.0166e-04
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0039 - val_loss: 8.3043e-04
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0033 - val_loss: 6.0986e-04
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - loss: 0.0036 - val_loss: 6.6618e-04
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0037 - val_loss: 6.0152e-04
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0038 - val_loss: 6.7746e-04
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0030 - val_loss: 6.8082e-04
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0034 - val_loss: 8.6797e-04
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0031 - val_loss: 5.9635e-04
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0030 - val_loss: 7.1295e-04
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0033 - val_loss: 9.8602e-04
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0030 - val_loss: 8.0439e-04
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0030 - val_loss: 6.8480e-04
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0030 - val_loss: 8.8451e-04
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Đánh giá mô hình LSTM:
# RMSE: 12.5010
# MAE: 9.7920
# R²: 0.8817
#
# Đánh giá mô hình XGBoost:
# RMSE: 8.4494
# MAE: 6.3747
# R²: 0.9459
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.0768 - val_loss: 0.0024
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0090 - val_loss: 0.0179
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0046 - val_loss: 0.0157
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0055 - val_loss: 0.0048
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0039 - val_loss: 0.0047
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0032 - val_loss: 0.0051
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0038 - val_loss: 0.0045
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0033 - val_loss: 0.0053
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0034 - val_loss: 0.0044
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0033 - val_loss: 0.0046
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0029 - val_loss: 6.4718e-04
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0044 - val_loss: 0.0099
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0026 - val_loss: 0.0022
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0027 - val_loss: 0.0013
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0026 - val_loss: 7.1330e-04
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0029 - val_loss: 0.0026
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
# Đánh giá mô hình LSTM:
# RMSE: 26.9906
# MAE: 21.3429
# R²: 0.5755
#
# Đánh giá mô hình XGBoost:
# RMSE: 65.5259
# MAE: 52.5172
# R²: -1.5018
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - loss: 0.0593 - val_loss: 0.0063
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0056 - val_loss: 0.0078
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0047 - val_loss: 0.0027
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0037 - val_loss: 0.0039
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0029 - val_loss: 0.0014
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - val_loss: 0.0013
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0033 - val_loss: 0.0049
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0031 - val_loss: 0.0016
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0029 - val_loss: 0.0028
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step
# Đánh giá mô hình LSTM:
# RMSE: 25.0491
# MAE: 20.9647
# R²: 0.7963
#
# Đánh giá mô hình XGBoost:
# RMSE: 34.1398
# MAE: 21.8290
# R²: 0.6216
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - loss: 0.1075 - val_loss: 0.0124
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0068 - val_loss: 0.0041
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0052 - val_loss: 0.0049
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0046 - val_loss: 0.0062
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0039 - val_loss: 0.0068
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0037 - val_loss: 0.0057
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0041 - val_loss: 0.0051
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0030 - val_loss: 0.0051
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0033 - val_loss: 0.0050
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0032 - val_loss: 0.0103
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0026 - val_loss: 0.0059
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0030 - val_loss: 0.0054
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 142ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0022 - val_loss: 0.0083
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0025 - val_loss: 0.0044
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0022 - val_loss: 0.0057
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# Đánh giá mô hình LSTM:
# RMSE: 19.8811
# MAE: 15.8776
# R²: 0.5230
#
# Đánh giá mô hình XGBoost:
# RMSE: 14.9059
# MAE: 11.4074
# R²: 0.7319
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - loss: 0.0563 - val_loss: 0.0128
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 0.0134 - val_loss: 0.0070
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0089 - val_loss: 0.0056
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0087 - val_loss: 0.0053
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0081 - val_loss: 0.0071
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - loss: 0.0062 - val_loss: 0.0046
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0060 - val_loss: 0.0046
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - loss: 0.0050 - val_loss: 0.0039
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0047 - val_loss: 0.0076
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0061 - val_loss: 0.0038
# Epoch 21/50
# ...
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.0049 - val_loss: 0.0020
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0043 - val_loss: 0.0025
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0033 - val_loss: 0.0022
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0028 - val_loss: 0.0016
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0026 - val_loss: 0.0016
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0031 - val_loss: 0.0016
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# Đánh giá mô hình LSTM:
# RMSE: 42.8476
# MAE: 34.4920
# R²: 0.7957
#
# Đánh giá mô hình XGBoost:
# RMSE: 72.2957
# MAE: 49.3438
# R²: 0.4183
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 0.1241 - val_loss: 0.0172
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0148 - val_loss: 0.0134
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0086 - val_loss: 0.0042
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 0.0068 - val_loss: 0.0022
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 0.0074 - val_loss: 0.0085
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0065 - val_loss: 0.0110
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 0.0050 - val_loss: 0.0066
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0045 - val_loss: 0.0095
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0058 - val_loss: 0.0121
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0038 - val_loss: 0.0016
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0054 - val_loss: 0.0031
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - loss: 0.0043 - val_loss: 0.0018
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - loss: 0.0039 - val_loss: 0.0030
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0039 - val_loss: 0.0021
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# Đánh giá mô hình LSTM:
# RMSE: 69.0289
# MAE: 57.6081
# R²: 0.5245
#
# Đánh giá mô hình XGBoost:
# RMSE: 116.6459
# MAE: 85.0507
# R²: -0.3579
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 9s 110ms/step - loss: 0.0823 - val_loss: 0.0112
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0116 - val_loss: 0.0080
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0069 - val_loss: 0.0156
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0080 - val_loss: 0.0055
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0059 - val_loss: 0.0052
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0071 - val_loss: 0.0056
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0056 - val_loss: 0.0066
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0053 - val_loss: 0.0052
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0058 - val_loss: 0.0069
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0051 - val_loss: 0.0059
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0042 - val_loss: 0.0070
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0035 - val_loss: 0.0047
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0036 - val_loss: 0.0049
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0038 - val_loss: 0.0038
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0033 - val_loss: 0.0055
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0031 - val_loss: 0.0039
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0028 - val_loss: 0.0041
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0029 - val_loss: 0.0048
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0029 - val_loss: 0.0067
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# Đánh giá mô hình LSTM:
# RMSE: 29.9098
# MAE: 22.2764
# R²: 0.8212
#
# Đánh giá mô hình XGBoost:
# RMSE: 51.4039
# MAE: 36.1540
# R²: 0.4719
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - loss: 0.1247 - val_loss: 0.0097
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0135 - val_loss: 0.0092
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0097 - val_loss: 0.0049
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0089 - val_loss: 0.0051
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0085 - val_loss: 0.0046
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0071 - val_loss: 0.0043
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0061 - val_loss: 0.0048
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0085 - val_loss: 0.0043
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0074 - val_loss: 0.0045
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0067 - val_loss: 0.0041
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - loss: 0.0069 - val_loss: 0.0039
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0065 - val_loss: 0.0042
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0064 - val_loss: 0.0040
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 0.0058 - val_loss: 0.0034
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0061 - val_loss: 0.0034
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0073 - val_loss: 0.0037
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0058 - val_loss: 0.0046
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0053 - val_loss: 0.0035
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0059 - val_loss: 0.0032
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0053 - val_loss: 0.0032
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0050 - val_loss: 0.0035
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0050 - val_loss: 0.0030
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0046 - val_loss: 0.0028
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0044 - val_loss: 0.0026
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0049 - val_loss: 0.0025
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0045 - val_loss: 0.0024
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0041 - val_loss: 0.0022
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0040 - val_loss: 0.0022
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0033 - val_loss: 0.0025
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# Đánh giá mô hình LSTM:
# RMSE: 63.5835
# MAE: 53.3129
# R²: 0.7146
#
# Đánh giá mô hình XGBoost:
# RMSE: 98.4166
# MAE: 71.7133
# R²: 0.3162
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.0340 - val_loss: 0.0045
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0144 - val_loss: 0.0032
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0117 - val_loss: 0.0028
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0096 - val_loss: 0.0025
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.0098 - val_loss: 0.0030
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0080 - val_loss: 0.0022
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0070 - val_loss: 0.0054
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 0.0077 - val_loss: 0.0024
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0083 - val_loss: 0.0019
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0073 - val_loss: 0.0020
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0070 - val_loss: 0.0040
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0084 - val_loss: 0.0026
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0078 - val_loss: 0.0031
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0075 - val_loss: 0.0030
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0075 - val_loss: 0.0017
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0067 - val_loss: 0.0017
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0060 - val_loss: 0.0018
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0063 - val_loss: 0.0027
# Epoch 20/50
# 13/39 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0067

# %%
with open('/content/drive/MyDrive/data scientist/FinanceResearch/results_summary.json', 'w') as json_file:
    json.dump(results_summary, json_file, indent=4, default=str)

# %% [markdown]
# File json chứa thông tin kết quả chạy các mã cổ phiếu, trong đó kết quả của mỗi mã bao gồm:
# - Lưu kết quả mỗi lần huấn luyện của 2 model (XGBoost) và LSTM, khoảng tgian test (250 ngày)
# - Các thông số đánh giá RMSE, MAE, R2 MSE
# - Giá trị thực tế và giá trị dự đoán của 2 model trong tgian test
